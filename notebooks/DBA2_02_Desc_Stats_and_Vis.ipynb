# %% [markdown]
# <a href="https://colab.research.google.com/github/mschuessler/dba_lecture/blob/main/notebooks/DBA2_02_Desc_Stats_and_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Titanic Excercise
# ## Reading a csv file with Pandas
# Here we are using the function "read_csv" of the Pandas Libary to read a file called "titanic.csv". When we send this code to the Python interpreter that runs on a Collab Server (by pressing the play button) the python interpreter will execute this function. Since this is a function that reads data and we have given it a download link for a csv file the interpreted will download that file an read it as a dataframe.
#
# If everything works **read_csv will return a pandas dataframe which contains all the data that was in the csv file**. We save this dataframe into a variabel called "passengers" because the csv file contains passenger information of the Titanics last journey.
#
# The following line of code can be read as:
# 1) Call the function read_csv of the libary pandas with the argument "titanic.csv" (which is the path to the file)
# 2) Save the results that we get back when function is done into a new variable called passenders

# %%
passengers = pd.read_csv("https://raw.githubusercontent.com/mschuessler/dba_lecture/refs/heads/main/data/titanic.csv")

# %% [markdown]
# ## Inspecting the Pandas Dataframe
# Whatever came back from the read_csv function is now saved in "passengers". But remember that python is not strictly typed. This means at this point we do not know what data type "passenders" actually is.
# I highly recommend to check that every time you use a new function or when you are unsure, because it will help you to find out what you can do with this datatype. By calling the function type() and passing our passenger variable as argument we find out that passengers is a pandas dataframe. This information helps us to find documnetation of what we can do with this data type.
# [If we search for the datatype and "documentation"](https://www.google.com/search?q=pandas.core.frame.dataframe+documentation) we can already find usefull information of what we can now do with our variable "passenders".

# %%
type(passengers)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Viewing the contents of a dataframe
# Since we now know that we got a dataframe, we can now take a look inside. We do that as we would do it with any other variable that contains data, by simple creating a cell and just putting the variable name into it.
# Note that jupyter tells us that the dataframe has 891 rows and 12 columns. It also provides a preview of the data so we can get a glimpse of what data we are dealing with here. It shows us a few rows at the beginning of the table and a few rows at the end of the table. Now take a moment. Do you understand what scale type each column is and what information it contains? If its is not immediately apparent it might be worth to look for a documentation of the dataset and find that out.

# %%
passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Data Types and Sacle Types: **Apply your knowledge**:
# 1. What are the data types of the columns “Age” “Fare” and “Sex” in the passenger dataframe?
#
# 2. *What* scale type should “Age” “Fare” and “Sex” be? Do the data types match?

# %%
passengers.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Descriptive Statistics Numbers at one glance - **Apply your knowledge**:
# 3. Calculate the range, mean, median, standard deviation, Q1, Q3 for Age and Ticket Price.
# 4. Without calculating the skew: Is the distribution of ticket price and Age skewed?

# %%
passengers.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Asymetry, Peak and tail - **Apply your knowledge**:
# 5. Calculate the skew and kurtosis for Fare and Age.

# %%
passengers.Age.skew()
# Out:
# np.float64(0.38910778230082704)

# %%
passengers.Age.kurtosis()
# Out:
# np.float64(0.17827415364210353)

# %%
passengers.Fare.skew()
# Out:
# np.float64(4.787316519674893)

# %%
passengers.Fare.kurtosis()
# Out:
# np.float64(33.39814088089868)

# %% [markdown]
# # (None-) Parametric Central tendency - **Apply your knowledge**:
# 6. Report the central tendency for Age and Fare.
#     * The central tendency for Age is 29.7 (Mean)
#     * The central tendency for Fare is 14.45 (Median)
# 7. Report an appropriate central tendency for the “Sex" column.
#     * We should use the mode here

# %%
passengers.Sex.describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
passengers.Sex.mode()
# Out:
# 0    male
# Name: Sex, dtype: object

# %%
passengers.Sex.value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %% [markdown]
# ## Pie-Chart - **Apply your knowledge**:
# 8. Create a Pie Chart of the Ticket Class Passengers traveled in.

# %%
passengers.Pclass.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# ## Bar Charts - **Apply your knowledge**:
# 9. Create a Bar Chart of the Ticket Class Passengers traveled in.
#
# Note: ylim limits the y-Axis to range from 0 to 1, which is great because 1 is the maximum value theoretically possible.

# %%
passengers.Pclass.value_counts(normalize=True).plot.bar(ylim=(0,1))
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ## Histograms - **Apply your knowledge**:
# 10. Create a Histogram of the Ages of passengers.
# 11. Inspect the skew of the histogram visually - is it not skewed, postively skewed or negatively skewed?
#     * Answer: The Age of passender is postively skewed

# %%
passengers.Age.plot.hist(bins=16)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Box and Whisker Plots - **Apply your knowledge**:
# 12. Create a box plot of Age and Fare.
# 13. What conclusions can you draw from these graphs?
#     * For Age
#       * Postively skewed (Mean > Median)
#       * Half of all passenger were between 20 and 40 years old
#       * There were several people on board that were exceptionally old
#     * For Fare
#       * Very heavly postively skewed
#       * A lot of outliers (a few people payed a lot more than everybody else)
#       * We should use none-parametric measures here

# %%
passengers.Age.plot.box(showmeans=True, meanline=True)
# Out:
# <Axes: >

# %%
passengers.Fare.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ## Kerlnel Density Plot - **Apply your knowledge**:
# 14. Create a KDE plot of Fare.
# 15. What conclusions can you draw from this graph?
#     * For Fare
#       * Its pointy, so kurtosis is probaly high
#       * Its not symetric, but rather positively skewed
#     * For Age
#       * Not so pointy, kurtosis could be alright
#       * Not perfectly symetric but rather symetric. Skew could be ok.

# %%
passengers.Fare.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
passengers.Age.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Advanced Visulisations with GenAI - **Apply your knowledge**:
# 16. Create a QQ plot of Fare and Age, using the GenAi Feature of Colab.

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

sm.qqplot(passengers.Age, line='s')
plt.title('QQ Plot of Age')
plt.show()

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

sm.qqplot(passengers.Age.dropna(), line='s')
plt.title('QQ Plot of Age')
plt.show()

# %% [markdown]
# # Deciding on the use of parametric measures - **Apply your knowlege*
# 17. Inspect all the indicators of data being normally or not normally distributed we have gathered so far. Should we use parametric or none-parametric measures to answer question about Fare and Age of the passenger?
#     * We should use none-parametric for Fare
#     * We should use parametric for Age
